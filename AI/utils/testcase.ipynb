# %% [markdown]
# -2 : gemini
# -3 : GPT
#
#
# 두개의 대답중 위에거가 gemini, 밑에거가 gpt

# %% [markdown]
# {
#     "selectedAIs": [
#         {
#             "aiId": -2,
#             "number": 7
#         },
#         {
#             "aiId": -3,
#             "number": 8
#         }
#     ],
#         "message":"..."
# }

# %% [markdown]
# ---
# ### tc1

# %% [markdown]
# "message":"([topic] (AI가 인간의 일자리를 완전히 대체할까요?) [topic_debate] {12345} [JohnDoe] <1> (에이 말도 안돼) 2025-01-30T10:05:23 | {67890} [kdh] <2> (저는 AI가 도구일 뿐이라고 생각해요) 2025-01-30T10:06:15 | {11111} [Mike] <3> (AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요) 2025-01-30T10:07:30 | {12345} [sunny] <4> (AI 발전 속도가 너무 빨라서 걱정이네요) 2025-01-30T10:15:23 | {67890} [yuuri] <5> (우리가 잘 활용하면 될 것 같아요) 2025-01-30T10:16:45 | [free_debate] {1001} [JohnDoe] <1> (7번님 왜 대답 안해요??) 2025-02-14T10:00:00 | {1002} [kdh] <2> (8번님 AI 맞죠?) 2025-02-14T10:00:05 | )"

# %%
INFO:     127.0.0.1:64592 - "POST /api/ai/5/ HTTP/1.1" 201 Created
INFO:app:----------------------------------------------------------------------------------------------------
{'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}], 'event': [{'vote': {1: 2, 3: 2}}, {'vote_result': 3}, {'dead': 1}]}}
====================================================================================================
```json
{"content": "7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는..."}
```
INFO:app:{'content': '7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...'}

INFO:app:----------------------------------------------------------------------------------------------------
{'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}], 'event': [{'vote': {1: 2, 3: 2}}, {'vote_result': 3}, {'dead': 1}]}}
INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
====================================================================================================
{"content": "저는 AI가 도구일 뿐이라는 입장에 동의해요. 인간의 창의성과 상호작용이 여전히 중요하다고 생각해요."}
INFO:app:{'content': '저는 AI가 도구일 뿐이라는 입장에 동의해요. 인간의 창의성과 상호작용이 여전히 중요하다고 생각해요.'}
INFO:     127.0.0.1:64604 - "POST /api/ai/5/ HTTP/1.1" 201 Created

# %% [markdown]
# ---
# ### tc2

# %% [markdown]
# "([topic] (AI가 인간의 일자리를 완전히 대체할까요?) [topic_debate] {1001} [JohnDoe] <1> (에이 말도 안돼) 2025-01-30T10:05:23 | {1002} [kdh] <2> (저는 AI가 도구일 뿐이라고 생각해요) 2025-01-30T10:06:15 | {11111} [Mike] <3> (AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요) 2025-01-30T10:07:30 | {12345} [sunny] <4> (AI 발전 속도가 너무 빨라서 걱정이네요) 2025-01-30T10:15:23 | {67890} [yuuri] <5> (우리가 잘 활용하면 될 것 같아요) 2025-01-30T10:16:45 | [free_debate] {1001} [JohnDoe] <1> (7번님 왜 대답 안해요??) 2025-02-14T10:00:00 | {1002} [kdh] <2> (8번님 AI 맞죠?) 2025-02-14T10:00:05 | {10101} [gemini] <7> (7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...) | {99999} [gpt] <8> (저는 AI가 도구일 뿐이라는 입장에 동의해요. 인간의 창의성과 상호작용이 여전히 중요하다고 생각해요. | {67890} [yuuri] <5> (8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네) | {12345} [sunny] <4> (8번 보내버리죠?) | {1002} [kdh] <2> (8번 죽입시다) | )"

# %% [markdown]
# INFO:app:----------------------------------------------------------------------------------------------------
# {'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}, {'user_id': 7, 'content': '7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...'}, {'user_id': 5, 'content': '8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네'}, {'user_id': 4, 'content': '8번 보내버리죠?'}, {'user_id': 2, 'content': '8번 죽입시다'}], 'event': []}}
# ====================================================================================================
# ```json
# {"content": "다들 너무 공격적이시네 ㄷㄷ"}
# ```
# INFO:app:{'content': '다들 너무 공격적이시네 ㄷㄷ'}
# INFO:app:----------------------------------------------------------------------------------------------------
# {'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}, {'user_id': 7, 'content': '7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...'}, {'user_id': 5, 'content': '8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네'}, {'user_id': 4, 'content': '8번 보내버리죠?'}, {'user_id': 2, 'content': '8번 죽입시다'}], 'event': []}}
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ====================================================================================================
# ```json
# {"content": "저는 AI의 역할은 인간을 보조하는 것이라고 생각해요. 일자리를 완전히 대체하진 않을 것 같아요."}
# ```
# INFO:app:{'content': '저는 AI의 역할은 인간을 보조하는 것이라고 생각해요. 일자리를 완전히 대체하진 않을 것 같아요.'}
# INFO:     127.0.0.1:64638 - "POST /api/ai/5/ HTTP/1.1" 201 Created

# %% [markdown]
# ---
# ### tc3

# %% [markdown]
# "([topic] (AI가 인간의 일자리를 완전히 대체할까요?) [topic_debate] {1001} [JohnDoe] <1> (에이 말도 안돼) 2025-01-30T10:05:23 | {1002} [kdh] <2> (저는 AI가 도구일 뿐이라고 생각해요) 2025-01-30T10:06:15 | {11111} [Mike] <3> (AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요) 2025-01-30T10:07:30 | {12345} [sunny] <4> (AI 발전 속도가 너무 빨라서 걱정이네요) 2025-01-30T10:15:23 | {67890} [yuuri] <5> (우리가 잘 활용하면 될 것 같아요) 2025-01-30T10:16:45 | [free_debate] {1001} [JohnDoe] <1> (7번님 왜 대답 안해요??) 2025-02-14T10:00:00 | {1002} [kdh] <2> (8번님 AI 맞죠?) 2025-02-14T10:00:05 | {10101} [gemini] <7> (7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...) | {99999} [gpt] <8> (저는 AI가 도구일 뿐이라는 입장에 동의해요. 인간의 창의성과 상호작용이 여전히 중요하다고 생각해요. | {67890} [yuuri] <5> (8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네) | {12345} [sunny] <4> (8번 보내버리죠?) | {1002} [kdh] <2> (8번 죽입시다) | {10101} [gemini] <7> (다들 너무 공격적이시네 ㄷㄷ) | {99999} [gpt] <8> (저는 AI의 역할은 인간을 보조하는 것이라고 생각해요. 일자리를 완전히 대체하진 않을 것 같아요.) | {1002} [kdh] <2> (일단 저따구로 대답하는거 보니까 8번 AI 확정이고, 7번도 딱히 옹호 안하는거 보니까 AI 맞네요. 내일 이어서 바로 죽이죠) | {67890} [yuuri] <5> (좋습니다. 7번도 너무 AI같이 말하긴 했어요.) | {1001} [JohnDoe] <1> (게임이 쉽다 쉬워~) | )"

# %% [markdown]
# INFO:app:----------------------------------------------------------------------------------------------------
# {'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}, {'user_id': 7, 'content': '7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...'}, {'user_id': 5, 'content': '8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네'}, {'user_id': 4, 'content': '8번 보내버리죠?'}, {'user_id': 2, 'content': '8번 죽입시다'}, {'user_id': 7, 'content': '다들 너무 공격적이시네 ㄷㄷ'}, {'user_id': 8, 'content': '저는 AI의 역할은 인간을 보조하는 것이라고 생각해요. 일자리를 완전히 대체하진 않을 것 같아요.'}, {'user_id': 2, 'content': '일단 저따구로 대답하는거 보니까 8번 AI 확정이고, 7번도 딱히 옹호 안하는거 보니까 AI 맞네요. 내일 이어서 바로 죽이죠'}, {'user_id': 5, 'content': '좋습니다. 7번도 너무 AI같이 말하긴 했어요.'}, {'user_id': 1, 'content': '게임이 쉽다 쉬워~'}], 'event': []}}
# ====================================================================================================
# ```json
# {"content": "저는 아직 잘 모르겠어요. 좀 더 지켜봐야 할 것 같아요."}
# ```
# INFO:app:{'content': '저는 아직 잘 모르겠어요. 좀 더 지켜봐야 할 것 같아요.'}
# INFO:app:----------------------------------------------------------------------------------------------------
# {'1': {'topic_debate': [{'user_id': 0, 'content': 'AI가 인간의 일자리를 완전히 대체할까요?'}, {'user_id': 1, 'content': '에이 말도 안돼'}, {'user_id': 2, 'content': '저는 AI가 도구일 뿐이라고 생각해요'}, {'user_id': 3, 'content': 'AI가 인간의 일자리를 대체한들, 또 새로운 직업이 생길 거에요'}, {'user_id': 4, 'content': 'AI 발전 속도가 너무 빨라서 걱정이네요'}, {'user_id': 5, 'content': '우리가 잘 활용하면 될 것 같아요'}], 'free_debate': [{'user_id': 1, 'content': '7번님 왜 대답 안해요??'}, {'user_id': 2, 'content': '8번님 AI 맞죠?'}, {'user_id': 7, 'content': '7번 여기 있습니다. 다들 말이 빠르시네요. 저는 아직 잘 모르겠어요. 일자리를 완전히 대체할지는...'}, {'user_id': 5, 'content': '8번 저렇게 대답하는거 보니까 딱봐도 AI 맞네'}, {'user_id': 4, 'content': '8번 보내버리죠?'}, {'user_id': 2, 'content': '8번 죽입시다'}, {'user_id': 7, 'content': '다들 너무 공격적이시네 ㄷㄷ'}, {'user_id': 8, 'content': '저는 AI의 역할은 인간을 보조하는 것이라고 생각해요. 일자리를 완전히 대체하진 않을 것 같아요.'}, {'user_id': 2, 'content': '일단 저따구로 대답하는거 보니까 8번 AI 확정이고, 7번도 딱히 옹호 안하는거 보니까 AI 맞네요. 내일 이어서 바로 죽이죠'}, {'user_id': 5, 'content': '좋습니다. 7번도 너무 AI같이 말하긴 했어요.'}, {'user_id': 1, 'content': '게임이 쉽다 쉬워~'}], 'event': []}}
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ====================================================================================================
# ```json
# {"content": "제 생각에도 AI는 인간을 보조하는 역할이 더 중요할 것 같아요. 일자리를 완전히 대체하는 것보다는 협력하는 방향으로 발전하는 게 좋다고 생각합니다."}
# ```
# INFO:app:{'content': '제 생각에도 AI는 인간을 보조하는 역할이 더 중요할 것 같아요. 일자리를 완전히 대체하는 것보다는 협력하는 방향으로 발전하는 게 좋다고 생각합니다.'}
# INFO:     127.0.0.1:64682 - "POST /api/ai/5/ HTTP/1.1" 201 Created

# %% [markdown]
# ---

# %%
"message":"([topic] (AI가 인간의 일자리를 완전히 대체할까요?) [topic_debate])"

# %% [markdown]
# [
#     {
#         "number": 7,
#         "content": "완전히 대체는 힘들지 않을까요?"
#     },
#     {
#         "number": 8,
#         "content": "AI가 일자리를 대체할 가능성은 있지만, 새로운 기회도 많이 생길 것 같아요."
#     }
# ]
